# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
housing_df=pd.read_csv("housing_data.csv")
census_df=pd.read_csv("chicago_census_data.csv")

# %%
housing_census_df = pd.merge(housing_df, census_df, on="Zipcode")
housing_census_df.head()

#len(chicago_df)
# Out:
#    Zipcode  Median Rent  Median Home Value  Population  Median Age  \
# 0    60601       1944.0           391100.0       13887        37.6
# 1    60602       1666.0                NaN        1277        31.1
# 2    60603       1630.0                NaN        1197        26.7
# 3    60604       1835.0                NaN         668        40.6
# 4    60605       1865.0           284100.0       26188        33.6
#
#    Household Income  Per Capita Income  Poverty Count  Poverty Rate
# 0            110215              95152           1171      8.432347
# 1            115774              77279             32      2.505873
# 2            140114             106207            261     21.804511
# 3            114565             130966            127     19.011976
# 4            107811              81144           2312      8.828471

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
housing_census_df.to_csv("housing_census_data.csv", encoding="utf-8", index=False)

# %%
# plot rent vs household income
fig,axl = plt.subplots()
axl.set_facecolor('lavender')
plt.scatter(housing_census_df['Median Rent'], housing_census_df['Household Income'], edgecolor = 'black', marker='o')
plt.grid (color='white')
plt.title("Median Rent vs. Household Income by Zipcode")
plt.xlabel("Median Rent")
plt.ylabel("Household Income")
# Save Figure as png
plt.savefig("Rent_Vs_Household_income", bbox_inches='tight')
plt.show()

# %%
# plot rent vs Per Capita income
fig,axl = plt.subplots()
axl.set_facecolor('lavender')
plt.scatter(housing_census_df['Median Rent'], housing_census_df['Per Capita Income'], edgecolor = 'black', marker='o')
plt.grid (color='white')
plt.title("Median Rent vs. Per Capita Income by Zipcode")
plt.xlabel("Median Rent")
plt.ylabel("Per Capita Income")
# Save Figure as png
plt.savefig("Rent_Vs_PerCapita_income", bbox_inches='tight')
plt.show()

# %%
# plot rent vs Poverty Rate
fig,axl = plt.subplots()
axl.set_facecolor('lavender')
plt.scatter(housing_census_df['Median Rent'], housing_census_df['Poverty Rate'], edgecolor = 'black', marker='o')
plt.grid (color='white')
plt.title("Median Rent vs. Poverty Rate by Zipcode")
plt.xlabel("Median Rent")
plt.ylabel("Poverty Rate")
# Save Figure as png
plt.savefig("Rent_Vs_PovertyRate", bbox_inches='tight')
plt.show()
